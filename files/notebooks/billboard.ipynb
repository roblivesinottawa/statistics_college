# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# !file -i "../other_formats/billboard.csv"
# Out:
# ../other_formats/billboard.csv: regular file

# %%
df = pd.read_csv('../other_formats/billboard.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             317 non-null    int64
#  1   artist.inverted  317 non-null    object
#  2   track            317 non-null    object
#  3   time             317 non-null    object
#  4   genre            317 non-null    object
#  5   date.entered     317 non-null    object
#  6   date.peaked      317 non-null    object
#  7   x1st.week        317 non-null    int64
#  8   x2nd.week        312 non-null    float64
#  9   x3rd.week        307 non-null    float64
#  10  x4th.week        300 non-null    float64
#  11  x5th.week        292 non-null    float64
#  12  x6th.week        280 non-null    float64
#  13  x7th.week        269 non-null    float64
#  14  x8th.week        260 non-null    float64
#  15  x9th.week        253 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %%
df.isnull().sum()
# Out:
# year                 0
# artist.inverted      0
# track                0
# time                 0
# genre                0
#                   ...
# x72nd.week         317
# x73rd.week         317
# x74th.week         317
# x75th.week         317
# x76th.week         317
# Length: 83, dtype: int64

# %%
df.describe()
# Out:
#          year   x1st.week   x2nd.week   x3rd.week   x4th.week   x5th.week  \
# count   317.0  317.000000  312.000000  307.000000  300.000000  292.000000
# mean   2000.0   79.958991   71.173077   65.045603   59.763333   56.339041
# std       0.0   14.686865   18.200443   20.752302   22.324619   23.780022
# min    2000.0   15.000000    8.000000    6.000000    5.000000    2.000000
# 25%    2000.0   74.000000   63.000000   53.000000   44.750000   38.750000
# 50%    2000.0   81.000000   73.000000   66.000000   61.000000   57.000000
# 75%    2000.0   91.000000   84.000000   79.000000   76.000000   73.250000
# max    2000.0  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         x6th.week   x7th.week   x8th.week   x9th.week  ...  x67th.week  \
# count  280.000000  269.000000  260.000000  253.000000  ...         0.0
# mean    52.360714   49.219331   47.119231   46.343874  ...         NaN
# std     24.473273   25.654279   26.370782   27.136419  ...         NaN
# ...

# %%
df.genre.value_counts()
# Out:
# Rock           137
# Country         74
# Rap             58
# R&B             23
# Latin            9
# Pop              9
# Electronica      4
# Jazz             1
# Reggae           1
# Gospel           1
# Name: genre, dtype: int64

# %%
df[df.genre == 'Rap'].groupby('year').count()
# Out:
#       artist.inverted  track  time  genre  date.entered  date.peaked  \
# year
# 2000               58     58    58     58            58           58
#
#       x1st.week  x2nd.week  x3rd.week  x4th.week  ...  x67th.week  x68th.week  \
# year                                              ...
# 2000         58         57         55         54  ...           0           0
#
#       x69th.week  x70th.week  x71st.week  x72nd.week  x73rd.week  x74th.week  \
# year
# 2000           0           0           0           0           0           0
#
#       x75th.week  x76th.week
# year
# 2000           0           0
#
# [1 rows x 82 columns]

# %%
df.rename(columns={'artist.inverted': 'artist'}, inplace=True)

# %%
df.head()
# Out:
#    year               artist                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# ...

# %%
df.artist.value_counts()
# Out:
# Jay-Z                5
# Houston, Whitney     4
# Dixie Chicks, The    4
# Destiny's Child      3
# Limp Bizkit          3
#                     ..
# Carter, Aaron        1
# Ice Cube             1
# Wills, Mark          1
# Lucy Pearl           1
# Fragma               1
# Name: artist, Length: 228, dtype: int64

# %%
df.artist.unique()
# Out:
# array(["Destiny's Child", 'Santana', 'Savage Garden', 'Madonna',
#        'Aguilera, Christina', 'Janet', 'Iglesias, Enrique', 'Sisqo',
#        'Lonestar', "N'Sync", 'Vertical Horizon', 'Creed', 'Aaliyah',
#        'matchbox twenty', 'Carey, Mariah', 'Hill, Faith', 'Mya', 'Dream',
#        'Braxton, Toni', 'Anthony, Marc', '98¡', '3 Doors Down',
#        'Houston, Whitney', 'Joe', 'Jordan, Montell', 'Eminem', 'Pink',
#        'Mumba, Samantha', 'Blaque', 'Elliott, Missy "Misdemeanor"',
#        'Gray, Macy', 'Ruff Endz', 'Backstreet Boys, The', 'Nine Days',
#        'Dion, Celine', 'Blink-182', 'Eiffel 65', 'Badu, Erkyah', 'Nelly',
#        'Next', 'Kenny G', 'Sonique', 'Spears, Britney', 'Everclear',
#        'Ja Rule', 'Rimes, LeAnn', 'Smash Mouth', 'Jay-Z', 'Jagged Edge',
#        'Filter', 'Martin, Ricky', 'Mystikal', 'BBMak', 'Third Eye Blind',
#        'Red Hot Chili Peppers', 'Profyle', 'Barenaked Ladies', '504 Boyz',
# ...

# %%
df.artist.nunique()
# Out:
# 228

# %%
df.head()
# Out:
#    year               artist                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# ...

# %%
df.tail()
# Out:
#      year            artist             track  time genre date.entered  \
# 312  2000  Ghostface Killah  Cherchez LaGhost  3:04   R&B   2000-08-05
# 313  2000       Smith, Will       Freakin' It  3:58   Rap   2000-02-12
# 314  2000     Zombie Nation     Kernkraft 400  3:30  Rock   2000-09-02
# 315  2000    Eastsidaz, The          Got Beef  3:58   Rap   2000-07-01
# 316  2000            Fragma    Toca's Miracle  3:22   R&B   2000-10-28
#
#     date.peaked  x1st.week  x2nd.week  x3rd.week  ...  x67th.week  x68th.week  \
# 312  2000-08-05         98        NaN        NaN  ...         NaN         NaN
# 313  2000-02-12         99       99.0       99.0  ...         NaN         NaN
# 314  2000-09-02         99       99.0        NaN  ...         NaN         NaN
# 315  2000-07-01         99       99.0        NaN  ...         NaN         NaN
# 316  2000-10-28         99        NaN        NaN  ...         NaN         NaN
#
# ...

# %%
df.year.unique()
# Out:
# array([2000])

# %%
df.loc[df.artist == 'Smith, Will']
# Out:
#      year       artist        track  time genre date.entered date.peaked  \
# 313  2000  Smith, Will  Freakin' It  3:58   Rap   2000-02-12  2000-02-12
#
#      x1st.week  x2nd.week  x3rd.week  ...  x67th.week  x68th.week  x69th.week  \
# 313         99       99.0       99.0  ...         NaN         NaN         NaN
#
#      x70th.week  x71st.week  x72nd.week  x73rd.week  x74th.week  x75th.week  \
# 313         NaN         NaN         NaN         NaN         NaN         NaN
#
#      x76th.week
# 313         NaN
#
# [1 rows x 83 columns]

# %%
sns.countplot(x='year', data=df.head(10), hue='artist')
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
sns.countplot(x='year', data=df.tail(10), hue='artist')
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
# how many songs did the Beatles have in the top 10?
df.loc[df.artist == 'The Beatles'].groupby('year').count()
# Out:
# Empty DataFrame
# Columns: [artist, track, time, genre, date.entered, date.peaked, x1st.week, x2nd.week, x3rd.week, x4th.week, x5th.week, x6th.week, x7th.week, x8th.week, x9th.week, x10th.week, x11th.week, x12th.week, x13th.week, x14th.week, x15th.week, x16th.week, x17th.week, x18th.week, x19th.week, x20th.week, x21st.week, x22nd.week, x23rd.week, x24th.week, x25th.week, x26th.week, x27th.week, x28th.week, x29th.week, x30th.week, x31st.week, x32nd.week, x33rd.week, x34th.week, x35th.week, x36th.week, x37th.week, x38th.week, x39th.week, x40th.week, x41st.week, x42nd.week, x43rd.week, x44th.week, x45th.week, x46th.week, x47th.week, x48th.week, x49th.week, x50th.week, x51st.week, x52nd.week, x53rd.week, x54th.week, x55th.week, x56th.week, x57th.week, x58th.week, x59th.week, x60th.week, x61st.week, x62nd.week, x63rd.week, x64th.week, x65th.week, x66th.week, x67th.week, x68th.week, x69th.week, x70th.week, x71st.week, x72nd.week, x73rd.week, x74th.week, x75th.week, x76th.week]
# Index: []
# ...

# %%
# how many songs did the Destiny's Child have in the top 10?
df.loc[df.artist == 'Destiny\'s Child'].groupby('year').count()
# Out:
#       artist  track  time  genre  date.entered  date.peaked  x1st.week  \
# year
# 2000       3      3     3      3             3            3          3
#
#       x2nd.week  x3rd.week  x4th.week  ...  x67th.week  x68th.week  \
# year                                   ...
# 2000          3          3          3  ...           0           0
#
#       x69th.week  x70th.week  x71st.week  x72nd.week  x73rd.week  x74th.week  \
# year
# 2000           0           0           0           0           0           0
#
#       x75th.week  x76th.week
# year
# 2000           0           0
#
# [1 rows x 82 columns]

# %%
df.columns
# Out:
# Index(['year', 'artist', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %%
# find information on Eminem 
df.loc[df.artist == 'Eminem'].groupby('year').count()
# Out:
#       artist  track  time  genre  date.entered  date.peaked  x1st.week  \
# year
# 2000       3      3     3      3             3            3          3
#
#       x2nd.week  x3rd.week  x4th.week  ...  x67th.week  x68th.week  \
# year                                   ...
# 2000          3          3          3  ...           0           0
#
#       x69th.week  x70th.week  x71st.week  x72nd.week  x73rd.week  x74th.week  \
# year
# 2000           0           0           0           0           0           0
#
#       x75th.week  x76th.week
# year
# 2000           0           0
#
# [1 rows x 82 columns]

# %%
df.artist
# Out:
# 0          Destiny's Child
# 1                  Santana
# 2            Savage Garden
# 3                  Madonna
# 4      Aguilera, Christina
#               ...
# 312       Ghostface Killah
# 313            Smith, Will
# 314          Zombie Nation
# 315         Eastsidaz, The
# 316                 Fragma
# Name: artist, Length: 317, dtype: object

# %%
df.loc[df.artist == 'Eastsidaz, The'].track
# Out:
# 168      G'D Up
# 315    Got Beef
# Name: track, dtype: object

# %%
df.head()
# Out:
#    year               artist                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# ...

# %%
# what is the longest a song remained in the top 10?
df.groupby('year').track.max()
# Out:
# year
# 2000    www.memory
# Name: track, dtype: object

# %%
df.query('track == "The Way I Am"').artist
# Out:
# 206    Eminem
# Name: artist, dtype: object

# %%
df.query('track == "The Way I Am"')
# Out:
#      year  artist         track  time genre date.entered date.peaked  \
# 206  2000  Eminem  The Way I Am  4:40   Rap   2000-08-26  2000-09-30
#
#      x1st.week  x2nd.week  x3rd.week  ...  x67th.week  x68th.week  x69th.week  \
# 206         87       74.0       59.0  ...         NaN         NaN         NaN
#
#      x70th.week  x71st.week  x72nd.week  x73rd.week  x74th.week  x75th.week  \
# 206         NaN         NaN         NaN         NaN         NaN         NaN
#
#      x76th.week
# 206         NaN
#
# [1 rows x 83 columns]

# %%
dfshort = df[['artist','track','time','date.entered','x1st.week','x2nd.week','x3rd.week']]

# %%
dfshort.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  x1st.week  x2nd.week  x3rd.week
# 0   2000-09-23         78       63.0       49.0
# 1   2000-02-12         15        8.0        6.0
# 2   1999-10-23         71       48.0       43.0
# 3   2000-08-12         41       23.0       18.0
# 4   2000-08-05         57       47.0       45.0

# %%
dfshort.columns = ['artist','track','time','date.entered','week1','week2','week3']

# %%
dfshort.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   date.entered  week1  week2  week3
# 0   2000-09-23     78   63.0   49.0
# 1   2000-02-12     15    8.0    6.0
# 2   1999-10-23     71   48.0   43.0
# 3   2000-08-12     41   23.0   18.0
# 4   2000-08-05     57   47.0   45.0

# %%
dfshort.artist.unique()
# Out:
# array(["Destiny's Child", 'Santana', 'Savage Garden', 'Madonna',
#        'Aguilera, Christina', 'Janet', 'Iglesias, Enrique', 'Sisqo',
#        'Lonestar', "N'Sync", 'Vertical Horizon', 'Creed', 'Aaliyah',
#        'matchbox twenty', 'Carey, Mariah', 'Hill, Faith', 'Mya', 'Dream',
#        'Braxton, Toni', 'Anthony, Marc', '98¡', '3 Doors Down',
#        'Houston, Whitney', 'Joe', 'Jordan, Montell', 'Eminem', 'Pink',
#        'Mumba, Samantha', 'Blaque', 'Elliott, Missy "Misdemeanor"',
#        'Gray, Macy', 'Ruff Endz', 'Backstreet Boys, The', 'Nine Days',
#        'Dion, Celine', 'Blink-182', 'Eiffel 65', 'Badu, Erkyah', 'Nelly',
#        'Next', 'Kenny G', 'Sonique', 'Spears, Britney', 'Everclear',
#        'Ja Rule', 'Rimes, LeAnn', 'Smash Mouth', 'Jay-Z', 'Jagged Edge',
#        'Filter', 'Martin, Ricky', 'Mystikal', 'BBMak', 'Third Eye Blind',
#        'Red Hot Chili Peppers', 'Profyle', 'Barenaked Ladies', '504 Boyz',
# ...

# %%
dfshort.query('artist == "Ghostface Killah"')
# Out:
#                artist             track  time date.entered  week1  week2  \
# 312  Ghostface Killah  Cherchez LaGhost  3:04   2000-08-05     98    NaN
#
#      week3
# 312    NaN

# %%
# get a sum of all the artists that start with the letter 'A'
dfshort.artist.str.startswith('A').sum()
# Out:
# 16

# %%
# get the names of all the artists that start with the letter 'A'
dfshort['artist'][dfshort.artist.str.startswith('A')]
# Out:
# 4      Aguilera, Christina
# 11     Aguilera, Christina
# 14                 Aaliyah
# 21           Anthony, Marc
# 26     Aguilera, Christina
# 89                   Avant
# 102                  Avant
# 109           Alice Deejay
# 135                Aaliyah
# 157                  Amber
# 200         Adams, Yolanda
# 227          Adkins, Trace
# 238          Anthony, Marc
# 268            Allan, Gary
# 301              Anastacia
# 304                A*Teens
# Name: artist, dtype: object
