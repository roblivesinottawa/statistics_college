# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/Users/rob_the_programmer/Documents/programming/2022/statistics/statistics-python-workspace/files/other_formats/Planets.xlsx', sheet_name='Fix 2')
df.head()
# Out:
#   Unnamed: 0  Mass   (10^24 kg)  Diameter (km)  Length of Day (hours)  \
# 0   MERCURY               0.330           4879                 4222.6
# 1     VENUS               4.870          12104                 2802.0
# 2     EARTH               5.970          12756                   24.0
# 3      MOON               0.073           3475                  708.7
# 4      MARS               0.642           6792                   24.7
#
#   Distance from Sun (106 km)  Orbital Period (days)  Orbital Velocity (km/s)  \
# 0                       57.9                   88.0                     47.4
# 1                      108.2                  224.7                     35.0
# 2                      149.6                  365.2                     29.8
# 3                     0.384*                   27.3                      1.0
# 4                      227.9                  687.0                     24.1
#
#    Mean Temperature (C) Surface Pressure (bars)  Number of Moons Ring System?  \
# ...

# %%
df.rename(columns={'Unnamed: 0': 'Planet'}, inplace=True)

# %%
df.head()
# Out:
#      Planet  Mass   (10^24 kg)  Diameter (km)  Length of Day (hours)  \
# 0  MERCURY               0.330           4879                 4222.6
# 1    VENUS               4.870          12104                 2802.0
# 2    EARTH               5.970          12756                   24.0
# 3     MOON               0.073           3475                  708.7
# 4     MARS               0.642           6792                   24.7
#
#   Distance from Sun (106 km)  Orbital Period (days)  Orbital Velocity (km/s)  \
# 0                       57.9                   88.0                     47.4
# 1                      108.2                  224.7                     35.0
# 2                      149.6                  365.2                     29.8
# 3                     0.384*                   27.3                      1.0
# 4                      227.9                  687.0                     24.1
#
#    Mean Temperature (C) Surface Pressure (bars)  Number of Moons Ring System?  \
# ...

# %%
df.to_csv('/Users/rob_the_programmer/Documents/programming/2022/statistics/statistics-python-workspace/files/other_formats/Planets_cleaned.csv')

# %%
df = pd.read_csv('../other_formats/Planets_cleaned.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0    Planet  Mass   (10^24 kg)  Diameter (km)  \
# 0           0  MERCURY               0.330           4879
# 1           1    VENUS               4.870          12104
# 2           2    EARTH               5.970          12756
# 3           3     MOON               0.073           3475
# 4           4     MARS               0.642           6792
#
#    Length of Day (hours) Distance from Sun (106 km)  Orbital Period (days)  \
# 0                 4222.6                       57.9                   88.0
# 1                 2802.0                      108.2                  224.7
# 2                   24.0                      149.6                  365.2
# 3                  708.7                     0.384*                   27.3
# 4                   24.7                      227.9                  687.0
#
#    Orbital Velocity (km/s)  Mean Temperature (C) Surface Pressure (bars)  \
# 0                     47.4                   167                       0
# ...

# %%
df.drop(['Unnamed: 0'], inplace=True, axis=1)

# %%
df.head()
# Out:
#      Planet  Mass   (10^24 kg)  Diameter (km)  Length of Day (hours)  \
# 0  MERCURY               0.330           4879                 4222.6
# 1    VENUS               4.870          12104                 2802.0
# 2    EARTH               5.970          12756                   24.0
# 3     MOON               0.073           3475                  708.7
# 4     MARS               0.642           6792                   24.7
#
#   Distance from Sun (106 km)  Orbital Period (days)  Orbital Velocity (km/s)  \
# 0                       57.9                   88.0                     47.4
# 1                      108.2                  224.7                     35.0
# 2                      149.6                  365.2                     29.8
# 3                     0.384*                   27.3                      1.0
# 4                      227.9                  687.0                     24.1
#
#    Mean Temperature (C) Surface Pressure (bars)  Number of Moons Ring System?  \
# ...

# %%
df = pd.read_csv('../other_formats/Planets_cleaned.csv', usecols=[1,2,3, 4])

# %%
df.head()
# Out:
#      Planet  Mass   (10^24 kg)  Diameter (km)  Length of Day (hours)
# 0  MERCURY               0.330           4879                 4222.6
# 1    VENUS               4.870          12104                 2802.0
# 2    EARTH               5.970          12756                   24.0
# 3     MOON               0.073           3475                  708.7
# 4     MARS               0.642           6792                   24.7

# %%
df.columns
# Out:
# Index(['Planet', 'Mass   (10^24 kg)', 'Diameter', 'Length of Day (hours)'], dtype='object')

# %%
df['Mass   (10^24 kg)']
# Out:
# 0       0.3300
# 1       4.8700
# 2       5.9700
# 3       0.0730
# 4       0.6420
# 5    1898.0000
# 6     568.0000
# 7      86.8000
# 8     102.0000
# 9       0.0146
# Name: Mass   (10^24 kg), dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.loc[0]
# Out:
# Planet                   MERCURY
# Mass   (10^24 kg)            0.33
# Diameter                     4879
# Length of Day (hours)      4222.6
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# Planet                   VENUS
# Mass   (10^24 kg)          4.87
# Diameter                  12104
# Length of Day (hours)    2802.0
# Name: 1, dtype: object

# %%
df.set_index('Planet', inplace=True)

# %%
df
# Out:
#           Mass   (10^24 kg)  Diameter  Length of Day (hours)
# Planet
# MERCURY              0.3300      4879                 4222.6
# VENUS                4.8700     12104                 2802.0
# EARTH                5.9700     12756                   24.0
# MOON                 0.0730      3475                  708.7
# MARS                 0.6420      6792                   24.7
# JUPITER           1898.0000    142984                    9.9
# SATURN             568.0000    120536                   10.7
# URANUS              86.8000     51118                   17.2
# NEPTUNE            102.0000     49528                   16.1
# PLUTO                0.0146      2370                  153.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, MERCURY  to PLUTO
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Mass   (10^24 kg)      10 non-null     float64
#  1   Diameter               10 non-null     int64
#  2   Length of Day (hours)  10 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 320.0+ bytes

# %%
len(df)
# Out:
# 10

# %%
df.head()
# Out:
#           Mass   (10^24 kg)  Diameter  Length of Day (hours)
# Planet
# MERCURY               0.330      4879                 4222.6
# VENUS                 4.870     12104                 2802.0
# EARTH                 5.970     12756                   24.0
# MOON                  0.073      3475                  708.7
# MARS                  0.642      6792                   24.7

# %%
df.iloc[0:3]
# Out:
#           Mass   (10^24 kg)  Diameter  Length of Day (hours)
# Planet
# MERCURY                0.33      4879                 4222.6
# VENUS                  4.87     12104                 2802.0
# EARTH                  5.97     12756                   24.0

# %%
df.columns
# Out:
# Index(['Mass   (10^24 kg)', 'Diameter', 'Length of Day (hours)'], dtype='object')

# %%
planets = pd.read_csv('../other_formats/Planets_cleaned.csv')

# %%
planets
# Out:
#    Unnamed: 0    Planet  Mass   (10^24 kg)  Diameter (km)  \
# 0           0  MERCURY              0.3300           4879
# 1           1    VENUS              4.8700          12104
# 2           2    EARTH              5.9700          12756
# 3           3     MOON              0.0730           3475
# 4           4     MARS              0.6420           6792
# 5           5  JUPITER           1898.0000         142984
# 6           6   SATURN            568.0000         120536
# 7           7   URANUS             86.8000          51118
# 8           8  NEPTUNE            102.0000          49528
# 9           9     PLUTO             0.0146           2370
#
#    Length of Day (hours) Distance from Sun (106 km)  Orbital Period (days)  \
# 0                 4222.6                       57.9                   88.0
# 1                 2802.0                      108.2                  224.7
# 2                   24.0                      149.6                  365.2
# ...

# %%
planets.drop(['Unnamed: 0'], inplace=True, axis=1)

# %%
planets
# Out:
#      Planet  Mass   (10^24 kg)  Diameter (km)  Length of Day (hours)  \
# 0  MERCURY              0.3300           4879                 4222.6
# 1    VENUS              4.8700          12104                 2802.0
# 2    EARTH              5.9700          12756                   24.0
# 3     MOON              0.0730           3475                  708.7
# 4     MARS              0.6420           6792                   24.7
# 5  JUPITER           1898.0000         142984                    9.9
# 6   SATURN            568.0000         120536                   10.7
# 7   URANUS             86.8000          51118                   17.2
# 8  NEPTUNE            102.0000          49528                   16.1
# 9     PLUTO             0.0146           2370                  153.3
#
#   Distance from Sun (106 km)  Orbital Period (days)  Orbital Velocity (km/s)  \
# 0                       57.9                   88.0                     47.4
# ...

# %%
planets.rename(columns={'Mass   (10^24 kg)': 'Mass'}, inplace=True)

# %%
planets
# Out:
#      Planet       Mass  Diameter (km)  Length of Day (hours)  \
# 0  MERCURY      0.3300           4879                 4222.6
# 1    VENUS      4.8700          12104                 2802.0
# 2    EARTH      5.9700          12756                   24.0
# 3     MOON      0.0730           3475                  708.7
# 4     MARS      0.6420           6792                   24.7
# 5  JUPITER   1898.0000         142984                    9.9
# 6   SATURN    568.0000         120536                   10.7
# 7   URANUS     86.8000          51118                   17.2
# 8  NEPTUNE    102.0000          49528                   16.1
# 9     PLUTO     0.0146           2370                  153.3
#
#   Distance from Sun (106 km)  Orbital Period (days)  Orbital Velocity (km/s)  \
# 0                       57.9                   88.0                     47.4
# 1                      108.2                  224.7                     35.0
# ...

# %%
# use a list comprehension to rename the columns
columns = ['Planet', 'Mass', 'Diameter', 'DayLength', 'SunDistance', 'OrbitPeriod',	'OrbitVelocity', 'MeanTemperature',	'SurfacePressure', 'Moons', 'Rings', 'MagneticField', 'FirstVisited', 'FirstMission']
planets.columns = columns

# %%
planets
# Out:
#      Planet       Mass  Diameter  DayLength SunDistance  OrbitPeriod  \
# 0  MERCURY      0.3300      4879     4222.6        57.9         88.0
# 1    VENUS      4.8700     12104     2802.0       108.2        224.7
# 2    EARTH      5.9700     12756       24.0       149.6        365.2
# 3     MOON      0.0730      3475      708.7      0.384*         27.3
# 4     MARS      0.6420      6792       24.7       227.9        687.0
# 5  JUPITER   1898.0000    142984        9.9       778.6       4331.0
# 6   SATURN    568.0000    120536       10.7      1433.5      10747.0
# 7   URANUS     86.8000     51118       17.2      2872.5      30589.0
# 8  NEPTUNE    102.0000     49528       16.1      4495.1      59800.0
# 9     PLUTO     0.0146      2370      153.3      5906.4      90560.0
#
#    OrbitVelocity  MeanTemperature SurfacePressure  Moons Rings MagneticField  \
# 0           47.4              167               0      0    No           Yes
# ...

# %%
df = planets

# %%
df.head()
# Out:
#      Planet   Mass  Diameter  DayLength SunDistance  OrbitPeriod  \
# 0  MERCURY   0.330      4879     4222.6        57.9         88.0
# 1    VENUS   4.870     12104     2802.0       108.2        224.7
# 2    EARTH   5.970     12756       24.0       149.6        365.2
# 3     MOON   0.073      3475      708.7      0.384*         27.3
# 4     MARS   0.642      6792       24.7       227.9        687.0
#
#    OrbitVelocity  MeanTemperature SurfacePressure  Moons Rings MagneticField  \
# 0           47.4              167               0      0    No           Yes
# 1           35.0              464              92      0    No            No
# 2           29.8               15               1      1    No           Yes
# 3            1.0              -20               0      0    No            No
# 4           24.1              -65            0.01      2    No            No
#
#   FirstVisited FirstMission
# 0   1974-03-29   Mariner 10
# 1   1962-08-27    Mariner 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Planet           10 non-null     object
#  1   Mass             10 non-null     float64
#  2   Diameter         10 non-null     int64
#  3   DayLength        10 non-null     float64
#  4   SunDistance      10 non-null     object
#  5   OrbitPeriod      10 non-null     float64
#  6   OrbitVelocity    10 non-null     float64
#  7   MeanTemperature  10 non-null     int64
#  8   SurfacePressure  10 non-null     object
#  9   Moons            10 non-null     int64
#  10  Rings            10 non-null     object
#  11  MagneticField    10 non-null     object
#  12  FirstVisited     9 non-null      object
#  13  FirstMission     9 non-null      object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 1.2+ KB

# %%
df.iloc[0: -1]
# Out:
#      Planet      Mass  Diameter  DayLength SunDistance  OrbitPeriod  \
# 0  MERCURY      0.330      4879     4222.6        57.9         88.0
# 1    VENUS      4.870     12104     2802.0       108.2        224.7
# 2    EARTH      5.970     12756       24.0       149.6        365.2
# 3     MOON      0.073      3475      708.7      0.384*         27.3
# 4     MARS      0.642      6792       24.7       227.9        687.0
# 5  JUPITER   1898.000    142984        9.9       778.6       4331.0
# 6   SATURN    568.000    120536       10.7      1433.5      10747.0
# 7   URANUS     86.800     51118       17.2      2872.5      30589.0
# 8  NEPTUNE    102.000     49528       16.1      4495.1      59800.0
#
#    OrbitVelocity  MeanTemperature SurfacePressure  Moons Rings MagneticField  \
# 0           47.4              167               0      0    No           Yes
# 1           35.0              464              92      0    No            No
# ...

# %%
df.columns
# Out:
# Index(['Planet', 'Mass', 'Diameter', 'DayLength', 'SunDistance', 'OrbitPeriod',
#        'OrbitVelocity', 'MeanTemperature', 'SurfacePressure', 'Moons', 'Rings',
#        'MagneticField', 'FirstVisited', 'FirstMission'],
#       dtype='object')

# %%
df.Planet
# Out:
# 0    MERCURY
# 1      VENUS
# 2      EARTH
# 3       MOON
# 4       MARS
# 5    JUPITER
# 6     SATURN
# 7     URANUS
# 8    NEPTUNE
# 9       PLUTO
# Name: Planet, dtype: object

# %%
df.Planet.unique()
# Out:
# array(['MERCURY\xa0', 'VENUS\xa0', 'EARTH\xa0', 'MOON\xa0', 'MARS\xa0',
#        'JUPITER\xa0', 'SATURN\xa0', 'URANUS\xa0', 'NEPTUNE\xa0', 'PLUTO'],
#       dtype=object)

# %%
df.FirstVisited
# Out:
# 0    1974-03-29
# 1    1962-08-27
# 2           NaN
# 3    1959-09-12
# 4    1965-07-15
# 5    1973-12-04
# 6    1979-09-01
# 7    1986-01-24
# 8    1989-08-25
# 9    2015-07-14
# Name: FirstVisited, dtype: object

# %%
# df.set_index('Planet', inplace=True)

# %%
df.head()
# Out:
#            Mass  Diameter  DayLength SunDistance  OrbitPeriod  OrbitVelocity  \
# Planet
# MERCURY   0.330      4879     4222.6        57.9         88.0           47.4
# VENUS     4.870     12104     2802.0       108.2        224.7           35.0
# EARTH     5.970     12756       24.0       149.6        365.2           29.8
# MOON      0.073      3475      708.7      0.384*         27.3            1.0
# MARS      0.642      6792       24.7       227.9        687.0           24.1
#
#           MeanTemperature SurfacePressure  Moons Rings MagneticField  \
# Planet
# MERCURY               167               0      0    No           Yes
# VENUS                 464              92      0    No            No
# EARTH                  15               1      1    No           Yes
# MOON                  -20               0      0    No            No
# MARS                  -65            0.01      2    No            No
#
#          FirstVisited FirstMission
# Planet
# ...

# %%
df.FirstVisited[0] # Mercury
# Out:
# '1974-03-29'

# %%
df.head(2)
# Out:
#           Mass  Diameter  DayLength SunDistance  OrbitPeriod  OrbitVelocity  \
# Planet
# MERCURY   0.33      4879     4222.6        57.9         88.0           47.4
# VENUS     4.87     12104     2802.0       108.2        224.7           35.0
#
#           MeanTemperature SurfacePressure  Moons Rings MagneticField  \
# Planet
# MERCURY               167               0      0    No           Yes
# VENUS                 464              92      0    No            No
#
#          FirstVisited FirstMission
# Planet
# MERCURY    1974-03-29   Mariner 10
# VENUS      1962-08-27    Mariner 2

# %%
df.iloc[0:-1]
# Out:
#               Mass  Diameter  DayLength SunDistance  OrbitPeriod  \
# Planet
# MERCURY      0.330      4879     4222.6        57.9         88.0
# VENUS        4.870     12104     2802.0       108.2        224.7
# EARTH        5.970     12756       24.0       149.6        365.2
# MOON         0.073      3475      708.7      0.384*         27.3
# MARS         0.642      6792       24.7       227.9        687.0
# JUPITER   1898.000    142984        9.9       778.6       4331.0
# SATURN     568.000    120536       10.7      1433.5      10747.0
# URANUS      86.800     51118       17.2      2872.5      30589.0
# NEPTUNE    102.000     49528       16.1      4495.1      59800.0
#
#           OrbitVelocity  MeanTemperature SurfacePressure  Moons Rings  \
# Planet
# MERCURY            47.4              167               0      0    No
# VENUS              35.0              464              92      0    No
# EARTH              29.8               15               1      1    No
# ...

# %%
earth = df.iloc[2]

# %%
print(earth)
# Out:
# Mass                5.97
# Diameter           12756
# DayLength           24.0
# SunDistance        149.6
# OrbitPeriod        365.2
# OrbitVelocity       29.8
# MeanTemperature       15
# SurfacePressure        1
# Moons                  1
# Rings                 No
# MagneticField        Yes
# FirstVisited         NaN
# FirstMission         NaN
# Name: EARTH , dtype: object

# %%
type(earth)
# Out:
# pandas.core.series.Series

# %%
df.FirstVisited = pd.to_datetime(df.FirstVisited)

# %%
df.FirstVisited.dt.year
# Out:
# Planet
# MERCURY     1974.0
# VENUS       1962.0
# EARTH          NaN
# MOON        1959.0
# MARS        1965.0
# JUPITER     1973.0
# SATURN      1979.0
# URANUS      1986.0
# NEPTUNE     1989.0
# PLUTO       2015.0
# Name: FirstVisited, dtype: float64

# %%
2021 - df.FirstVisited.dt.year
# Out:
# Planet
# MERCURY     47.0
# VENUS       59.0
# EARTH        NaN
# MOON        62.0
# MARS        56.0
# JUPITER     48.0
# SATURN      42.0
# URANUS      35.0
# NEPTUNE     32.0
# PLUTO        6.0
# Name: FirstVisited, dtype: float64
